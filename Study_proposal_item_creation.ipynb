# %% [markdown]
# Goal is to create tuples that contain nouns with the same animacy (similar group) and with different animacy (contrast group), to calculate their similarity values and to export the created dataframe for data analysis later on.

# %%
import csv
import pandas as pd
from gensim.models.word2vec import Text8Corpus
from gensim.models import Word2Vec

# %% [markdown]
# First of all, a csv file which contains animate and inanimate nouns is uploaded. The nouns stem from the brown corpus. By using nltk all nouns were extracted out of the brown corpus and randomized. After that, the first 150 animate and inanimte nouns were extracted. Pseudowords, Names, words that were not clearly assignable to the animate or inanimate category (the definition of animacy is explained in detail in the prestudy) or words that were not contained in the training dataset of the word2vec model were excluded.
#
# The path represents the place where the csv file is stored.
# This csv file is accessed and opend for reading purposes.
# All items are stored in one line and separated by ';'. The file, only containing line 0, has to be splitted in many parts after each ';', such that the items are accessible.
# All animate and inanimate nouns are extracted and stored in their correspinding lists.

# %%
file=open("Nouns_studyProposal.CSV", "r")

noun_file = csv.reader(file)

animate=[]
inanimate=[]
for line in noun_file:
    splitted_file=line[0].split(sep=";")
    animate.append(splitted_file[0])
    inanimate.append(splitted_file[1])
print(animate, inanimate)
# Out:
# ['Animate', 'guard', 'peoples', 'uncle', 'men', 'workers', 'fish', 'teacher', 'battalion', 'liberal', 'commentators', 'attorney', 'founders', 'beef', 'partner', 'principal', 'victim', 'girls', 'communists', 'coach', 'president', 'governance', 'peasant', 'daughters', 'employee', 'lady', 'master', 'commanders', 'delegates', 'tourists', 'mother', 'parent', 'commissioner', 'bird', 'dolphin', 'viewers', 'editor', 'individual', 'sons', 'scholars', 'chancellor', 'prisoners', 'wife', 'couple', 'lover', 'musicians', 'veterans', 'elite', 'couple', 'commanders', 'dealer', 'swan', 'researcher', 'bully', 'tiger', 'confessor', 'grandmother', 'shopkeeper', 'neighbor', 'militarist', 'supervisor', 'fishermen', 'lifeguard', 'catcher', 'maid', 'dispenser', 'sociologist', 'banker', 'piers', 'landlord', 'sinner', 'boss', 'proprietor', 'council', 'postmaster', 'sister', 'committee', 'eyewitness', 'developer', 'referent', 'boa', 'junior', 'amateur', 'misses', 'husband', 'shipmates', 'senator', 'pilot', 'pickers', 'buyer', 'liberals', 'astronomer', 'intellectuals', 'grandfathers', 'merchants', 'salesman', 'referee', 'stewardess', 'intruders', 'alcoholics', 'missionary', 'nurse', 'cobbler', 'builder', 'politician', 'racist', 'reporter', 'student', 'employers', 'celebrity', 'owner', 'humorist', 'liar', 'nationals', 'millionaire', 'bishop', 'mayor', 'artist', 'princess', 'householder', 'gymnast', 'customer', 'pianist', 'retailers', 'assassins', 'giant', 'planner', 'female', 'thinker', 'controller', 'civilian', 'craftsman', 'travellers', 'poets', 'analyst', 'sardines', 'preacher', 'youths', 'planters', 'purist', 'spectators', 'instructor', 'champions', 'police', 'selectors', 'graduate', 'contender', 'farmer', 'descendant', 'dancers', 'horse'] ['Inanimate', 'suffrage', 'incest', 'sea', 'demonstrations', 'definition', 'experiment', 'cosmology', 'canon', 'portrait', 'listing', 'protest', 'suburb', 'timber', 'studio', 'status', 'compensation', 'chronicle', 'convention', 'formation', 'doctrine', 'policies', 'boat', 'vectors', 'moment', 'discrimination', 'factors', 'panel', 'materials', 'management', 'switches', 'money', 'records', 'coal', 'needs', 'developments', 'opinion', 'names', 'hotel', 'octave', 'security', 'thesis', 'head', 'stick', 'groups', 'chambers', 'technique', 'boards', 'privacy', 'corruption', 'faith', 'pans', 'imperative', 'specimen', 'tracer', 'suffrage', 'arteries', 'engraving', 'canyon', 'wakefulness', 'logarithm', 'outrages', 'social', 'class', 'coal', 'contentment', 'malady', 'menu', 'charity', 'meantime', 'club', 'appointment', 'moral', 'siren', 'radius', 'lips', 'equal', 'helicopter', 'death', 'lemon', 'ice', 'application', 'result', 'findings', 'correlation', 'orchestra', 'denial', 'existence', 'heaven', 'agreement', 'collaboration', 'country', 'jacket', 'defeats', 'greetings', 'limit', 'illustration', 'sequence', 'hospitality', 'criterion', 'republic', 'hope', 'phonology', 'lingerie', 'concept', 'game', 'bar', 'press', 'city', 'cigarette', 'tradition', 'risk', 'building', 'handwriting', 'economy', 'lounge', 'doubts', 'benefits', 'margins', 'music', 'cartoon', 'night', 'cake', 'month', 'income', 'winter', 'foot', 'airplane', 'niche', 'taint', 'essays', 'town', 'nuclei', 'access', 'honour', 'membrane', 'dust', 'milligrams', 'fashion', 'explorations', 'quality', 'beginning', 'departure', 'tape', 'cerebellum', 'cooperative', 'plane', 'ear', 'finality', 'quote', 'arcades']

# %% [markdown]
# Since the first item of our two lists are the headings, we delete them. We don't want to have the headings in the tuples later on.

# %%
animate.pop(0)
inanimate.pop(0)
# Out:
# 'Inanimate'

# %% [markdown]
# We create our first data frame df which only contains our animate and inanimate items.

# %%
df = pd.DataFrame(list(zip(animate, inanimate)),
                          columns =['Animate', 'Inanimate'])
df
# Out:
#         Animate       Inanimate
# 0         guard        suffrage
# 1       peoples          incest
# 2         uncle             sea
# 3           men  demonstrations
# 4       workers      definition
# ..          ...             ...
# 145   contender           plane
# 146      farmer             ear
# 147  descendant        finality
# 148     dancers           quote
# 149       horse         arcades
#
# [150 rows x 2 columns]

# %% [markdown]
# We now want to check whether all nouns are in the training dataset. With missing nouns no similarity values can be calculated.
# To do so, we need to upload our word2vec model. We take the pre trained word vectors that have been trained on the text8 corpus. For the pre study we take the same min_count as in our main experiment later (min_count=5).

# %%
w2v_model = Word2Vec(
    Text8Corpus("text8"),
    size=100,
    window=5,
    min_count=5,
    workers=3)

# %% [markdown]
# To check whether all words of our two lists are contained in the training dataset we add two new columns to our dataframe that containes the boolien expression TRUE when a word is contained in the dataset and FALSE when it is not contained.
# We use the lambda function to check each row of the animate list and apply the result to the new column 'animate_inW2v'. We do the same for the contrast list. To be able to see the whole output we specify that we want to see all 150 rows in the output window.

# %%
#Check whether all words are in the training dataset
word_dict = w2v_model.wv.vocab
df['animate_inW2v'] = df.Animate.apply(lambda x: x in word_dict)
df['inanimate_inW2V'] = df.Inanimate.apply(lambda x: x in word_dict)
pd.set_option('display.max_rows', 150)
df
# Out:
#            Animate       Inanimate  animate_inW2v  inanimate_inW2V
# 0            guard        suffrage           True             True
# 1          peoples          incest           True             True
# 2            uncle             sea           True             True
# 3              men  demonstrations           True             True
# 4          workers      definition           True             True
# 5             fish      experiment           True             True
# 6          teacher       cosmology           True             True
# 7        battalion           canon           True             True
# 8          liberal        portrait           True             True
# 9     commentators         listing           True             True
# 10        attorney         protest           True             True
# 11        founders          suburb           True             True
# 12            beef          timber           True             True
# 13         partner          studio           True             True
# 14       principal          status           True             True
# 15          victim    compensation           True             True
# 16           girls       chronicle           True             True
# 17      communists      convention           True             True
# 18           coach       formation           True             True
# 19       president        doctrine           True             True
# 20      governance        policies           True             True
# 21         peasant            boat           True             True
# 22       daughters         vectors           True             True
# 23        employee          moment           True             True
# 24            lady  discrimination           True             True
# 25          master         factors           True             True
# 26      commanders           panel           True             True
# 27       delegates       materials           True             True
# 28        tourists      management           True             True
# 29          mother        switches           True             True
# 30          parent           money           True             True
# 31    commissioner         records           True             True
# 32            bird            coal           True             True
# 33         dolphin           needs           True             True
# 34         viewers    developments           True             True
# 35          editor         opinion           True             True
# 36      individual           names           True             True
# 37            sons           hotel           True             True
# 38        scholars          octave           True             True
# 39      chancellor        security           True             True
# 40       prisoners          thesis           True             True
# 41            wife            head           True             True
# 42          couple           stick           True             True
# 43           lover          groups           True             True
# 44       musicians        chambers           True             True
# 45        veterans       technique           True             True
# 46           elite          boards           True             True
# 47          couple         privacy           True             True
# 48      commanders      corruption           True             True
# 49          dealer           faith           True             True
# 50            swan            pans           True             True
# 51      researcher      imperative           True             True
# 52           bully        specimen           True             True
# 53           tiger          tracer           True             True
# 54       confessor        suffrage           True             True
# 55     grandmother        arteries           True             True
# 56      shopkeeper       engraving           True             True
# 57        neighbor          canyon           True             True
# 58      militarist     wakefulness           True             True
# 59      supervisor       logarithm           True             True
# 60       fishermen        outrages           True             True
# 61       lifeguard          social           True             True
# 62         catcher           class           True             True
# 63            maid            coal           True             True
# 64       dispenser     contentment           True             True
# 65     sociologist          malady           True             True
# 66          banker            menu           True             True
# 67           piers         charity           True             True
# 68        landlord        meantime           True             True
# 69          sinner            club           True             True
# 70            boss     appointment           True             True
# 71      proprietor           moral           True             True
# 72         council           siren           True             True
# 73      postmaster          radius           True             True
# 74          sister            lips           True             True
# 75       committee           equal           True             True
# 76      eyewitness      helicopter           True             True
# 77       developer           death           True             True
# 78        referent           lemon           True             True
# 79             boa             ice           True             True
# 80          junior     application           True             True
# 81         amateur          result           True             True
# 82          misses        findings           True             True
# 83         husband     correlation           True             True
# 84       shipmates       orchestra           True             True
# 85         senator          denial           True             True
# 86           pilot       existence           True             True
# 87         pickers          heaven           True             True
# 88           buyer       agreement           True             True
# 89        liberals   collaboration           True             True
# 90      astronomer         country           True             True
# 91   intellectuals          jacket           True             True
# 92    grandfathers         defeats           True             True
# 93       merchants       greetings           True             True
# 94        salesman           limit           True             True
# 95         referee    illustration           True             True
# 96      stewardess        sequence           True             True
# 97       intruders     hospitality           True             True
# 98      alcoholics       criterion           True             True
# 99      missionary        republic           True             True
# 100          nurse            hope           True             True
# 101        cobbler       phonology           True             True
# 102        builder        lingerie           True             True
# 103     politician         concept           True             True
# 104         racist            game           True             True
# 105       reporter             bar           True             True
# 106        student           press           True             True
# 107      employers            city           True             True
# 108      celebrity       cigarette           True             True
# 109          owner       tradition           True             True
# 110       humorist            risk           True             True
# 111           liar        building           True             True
# 112      nationals     handwriting           True             True
# 113    millionaire         economy           True             True
# 114         bishop          lounge           True             True
# 115          mayor          doubts           True             True
# 116         artist        benefits           True             True
# 117       princess         margins           True             True
# 118    householder           music           True             True
# 119        gymnast         cartoon           True             True
# 120       customer           night           True             True
# 121        pianist            cake           True             True
# 122      retailers           month           True             True
# 123      assassins          income           True             True
# 124          giant          winter           True             True
# 125        planner            foot           True             True
# 126         female        airplane           True             True
# 127        thinker           niche           True             True
# 128     controller           taint           True             True
# 129       civilian          essays           True             True
# 130      craftsman            town           True             True
# 131     travellers          nuclei           True             True
# 132          poets          access           True             True
# 133        analyst          honour           True             True
# 134       sardines        membrane           True             True
# 135       preacher            dust           True             True
# 136         youths      milligrams           True             True
# 137       planters         fashion           True             True
# 138         purist    explorations           True             True
# 139     spectators         quality           True             True
# 140     instructor       beginning           True             True
# 141      champions       departure           True             True
# 142         police            tape           True             True
# 143      selectors      cerebellum           True             True
# 144       graduate     cooperative           True             True
# 145      contender           plane           True             True
# 146         farmer             ear           True             True
# 147     descendant        finality           True             True
# 148        dancers           quote           True             True
# 149          horse         arcades           True             True

# %% [markdown]
# We can see that indeed every word is contained in the training dataset which means that we can continue...

# %% [markdown]
# The next goal is to create a data frame that containes tuples (pairs of nouns). One column should contain tuples with nouns with the same animacy (similar_tuples) and one column should contain tuples with nouns with different animacy (contrast_tuples).

# %% [markdown]
# To create those tuples we start by extracting the 'Animate' and 'Inanimate' column out of our dataframe df and create two separate lists, containing the corresponding items.

# %%
Animate = list(df['Animate'])
Inanimate = list(df['Inanimate'])

# %% [markdown]
# Each tuple of the form (a,b) of the similar and the contrast group, has a target item a at the first place. This target item ‘a’ is compared with another item ‘b’, where ‘b’ is either an item of the same animacy as ‘a’ for tuples of the similar group or an item with different animacy for tuples of the contrast group.

# %% [markdown]
# To create the tuples for the similar group, every fourth word, starting at the first item of the animate and the inanimate list is stored in a separate list ‘list_a’. All items of ‘list_a’ are target items and stand in the first position in the similar and the contrast group tuples.
# Every fourth word starting at the third word of the animate and inanimate list are stored in another list ‘similar_list_b’. The tuples of the similar list have the format (list_a[i], similar_list_b[i]), where i is representing the row number of both lists. For each tuple a similarity value is calculated.

# %%
# create the similar group: always pair the two items that are one below the other (just within the groups)

list_Animate_a = Animate[0::4]
similar_list_Animate_b = Animate[2::4]
list_Inanimate_a = Inanimate[0::4]
similar_list_Inanimate_b = Inanimate[2::4]

list_a = list_Animate_a + list_Inanimate_a
list_a = list_a[0:74]
similar_list_b = similar_list_Animate_b + similar_list_Inanimate_b

# %%
len(list_a)
# Out:
# 74

# %%
len(similar_list_b)
# Out:
# 74

# %% [markdown]
# Now that we have the two lists that we need to create our similar tuples, we store them in a new dataframe called df_similar.
# Next, we want to calculate the similarity between the two words that are in each row (word x of list a with word x of list b).
# To do so, we assign the similarity function to the variable sim. We then use again the lambda function to apply the similarity function for each row of the dataframe and store the results in a new column called 'simval_similar'

# %%
#Create a pandas dataframe for the similar dataset
df_similar = pd.DataFrame(list(zip(list_a, similar_list_b)),
                          columns =['list_a', 'similar_list_b'])
sim = w2v_model.wv.similarity 
df_similar['simval_similar'] = df_similar.apply(lambda row: sim(row.list_a, row.similar_list_b), axis=1)
df_similar
# Out:
#             list_a similar_list_b  simval_similar
# 0            guard          uncle        0.182770
# 1          workers        teacher        0.001084
# 2          liberal       attorney        0.242627
# 3             beef      principal        0.146274
# 4            girls          coach        0.340212
# 5       governance      daughters       -0.098016
# 6             lady     commanders        0.081941
# 7         tourists         parent        0.028724
# 8             bird        viewers        0.045432
# 9       individual       scholars        0.045291
# 10       prisoners         couple        0.209063
# 11       musicians          elite        0.331757
# 12      commanders           swan       -0.167004
# 13           bully      confessor        0.368751
# 14      shopkeeper     militarist        0.330522
# 15       fishermen        catcher        0.214114
# 16       dispenser         banker        0.230466
# 17        landlord           boss        0.299832
# 18         council         sister       -0.045183
# 19      eyewitness       referent        0.119972
# 20          junior         misses        0.205991
# 21       shipmates          pilot        0.250103
# 22           buyer     astronomer       -0.055982
# 23    grandfathers       salesman        0.136869
# 24      stewardess     alcoholics        0.179674
# 25           nurse        builder        0.322403
# 26          racist        student        0.078734
# 27       celebrity       humorist        0.420508
# 28       nationals         bishop        0.200379
# 29          artist    householder        0.277932
# 30        customer      retailers        0.419900
# 31           giant         female        0.246917
# 32      controller      craftsman        0.217844
# 33           poets       sardines        0.173646
# 34          youths         purist        0.360616
# 35      instructor         police        0.317000
# 36        graduate         farmer        0.146009
# 37         dancers            sea       -0.087450
# 38        suffrage      cosmology        0.033932
# 39      definition        protest       -0.074392
# 40        portrait         status        0.031062
# 41          timber      formation        0.132468
# 42       chronicle        vectors       -0.190265
# 43        policies          panel        0.118198
# 44  discrimination          money        0.324850
# 45      management   developments        0.171838
# 46            coal         octave       -0.032916
# 47           names          stick        0.028048
# 48          thesis         boards        0.119463
# 49        chambers           pans        0.360667
# 50      corruption       suffrage        0.292685
# 51        specimen    wakefulness        0.232715
# 52       engraving          class       -0.091368
# 53        outrages           menu        0.168130
# 54     contentment    appointment       -0.010817
# 55        meantime           lips        0.021014
# 56           siren          lemon        0.470373
# 57      helicopter       findings       -0.177541
# 58     application      existence        0.328688
# 59       orchestra        country       -0.042992
# 60       agreement          limit        0.232633
# 61         defeats      criterion       -0.262271
# 62        sequence       lingerie       -0.173352
# 63            hope          press        0.123554
# 64            game           risk        0.164620
# 65       cigarette         lounge        0.480527
# 66     handwriting          music        0.189189
# 67        benefits          month        0.016746
# 68           night       airplane        0.249739
# 69          winter           town        0.239006
# 70           taint       membrane        0.113514
# 71          access   explorations        0.098390
# 72      milligrams           tape        0.142123
# 73       beginning            ear       -0.043757

# %% [markdown]
# We do the same for the contrast tuples.

# %%
# create the contrast group: always pair the two items that are in the same row (animate with inanimate)

Inanimate_contrast_list_b = Inanimate[1::4]
Animate_contrast_list_b = Animate[1::4]

contrast_list_b = Inanimate_contrast_list_b+Animate_contrast_list_b

df_contrast = pd.DataFrame(list(zip(list_a, contrast_list_b)),
                          columns =['list_a', 'contrast_list_b'])
df_contrast['simval_contrast'] = df_contrast.apply(lambda row: sim(row.list_a, row.contrast_list_b), axis=1)
df_contrast
# Out:
#             list_a contrast_list_b  simval_contrast
# 0            guard          incest        -0.146781
# 1          workers      experiment        -0.077382
# 2          liberal         listing        -0.161327
# 3             beef          studio         0.103131
# 4            girls      convention        -0.255836
# 5       governance            boat        -0.134900
# 6             lady         factors        -0.220688
# 7         tourists        switches         0.029916
# 8             bird           needs        -0.017414
# 9       individual           hotel        -0.205426
# 10       prisoners            head         0.110111
# 11       musicians       technique         0.267431
# 12      commanders           faith         0.039719
# 13           bully          tracer         0.297017
# 14      shopkeeper          canyon         0.208013
# 15       fishermen          social        -0.098994
# 16       dispenser          malady         0.209961
# 17        landlord            club         0.144067
# 18         council          radius         0.026034
# 19      eyewitness           death         0.166206
# 20          junior          result        -0.118856
# 21       shipmates          denial         0.185855
# 22           buyer   collaboration         0.108021
# 23    grandfathers       greetings         0.186627
# 24      stewardess     hospitality         0.452524
# 25           nurse       phonology        -0.110809
# 26          racist             bar        -0.183519
# 27       celebrity       tradition        -0.020186
# 28       nationals         economy         0.333311
# 29          artist         margins        -0.123720
# 30        customer            cake         0.004981
# 31           giant            foot         0.263052
# 32      controller          essays        -0.060296
# 33           poets          honour         0.277034
# 34          youths         fashion         0.106573
# 35      instructor       departure         0.230123
# 36        graduate           plane        -0.061194
# 37         dancers         arcades         0.262599
# 38        suffrage         peoples         0.076852
# 39      definition            fish        -0.107815
# 40        portrait    commentators        -0.053316
# 41          timber         partner         0.004817
# 42       chronicle      communists        -0.070540
# 43        policies         peasant         0.128682
# 44  discrimination          master        -0.074105
# 45      management          mother        -0.127858
# 46            coal         dolphin         0.291688
# 47           names            sons         0.280298
# 48          thesis            wife         0.202716
# 49        chambers        veterans        -0.044882
# 50      corruption          dealer        -0.036889
# 51        specimen           tiger         0.296359
# 52       engraving        neighbor         0.153151
# 53        outrages       lifeguard         0.651547
# 54     contentment     sociologist         0.337322
# 55        meantime          sinner         0.135675
# 56           siren      postmaster         0.453691
# 57      helicopter       developer         0.119899
# 58     application         amateur         0.178576
# 59       orchestra         senator         0.101419
# 60       agreement        liberals         0.241860
# 61         defeats       merchants         0.231236
# 62        sequence       intruders         0.021863
# 63            hope         cobbler         0.135995
# 64            game        reporter         0.095063
# 65       cigarette           owner         0.246835
# 66     handwriting     millionaire         0.016861
# 67        benefits        princess        -0.271706
# 68           night         pianist         0.040755
# 69          winter         planner        -0.132066
# 70           taint        civilian         0.030646
# 71          access         analyst        -0.004176
# 72      milligrams        planters         0.032068
# 73       beginning       champions         0.227130

# %% [markdown]
# For the data analysis we do not want the words that belong to one tuple in seperate columns. We want one column for all tuples of the similar and one for all tuples of the contrast group. Therefore, we create tuples of the format (list_a[i], similar_list_b[i]) for the similar group and tuples of the format (list_a[i], contrast_list_b[i]) for the contrast group.

# %%
similar_tuples=[(similar_list_a[i],similar_list_b[i]) for i in range(0,len(similar_list_a))]

                
contrast_tuples=[(contrast_list_a[i],contrast_list_b[i]) for i in range(0,len(contrast_list_a))]

# %% [markdown]
# Now we want to create the final data frame. It should contain one columns with the similar tuples, then a column containing the corresponding similarity values, after that a column with the contrast tuples and again the corresponding similarity values.
#
# To do so, we extract the already calculated similarity values out of the similar and the contrast dataframe and create the new dataframe calles df_simval with all needed columns.

# %%
simval_similar = list(df_similar['simval_similar'])
simval_contrast = list(df_contrast['simval_contrast'])
df_simval = pd.DataFrame(list(zip(similar_tuples, simval_similar, contrast_tuples, simval_contrast)),
                          columns =['Similar_tuples', 'Simval_similar', 'Contrast_tuples', 'Simval_contrast'])
df_simval
# Out:
#                 Similar_tuples  Simval_similar             Contrast_tuples  \
# 0               (guard, uncle)        0.171724             (guard, incest)
# 1           (workers, teacher)        0.044274       (workers, experiment)
# 2          (liberal, attorney)        0.234067          (liberal, listing)
# 3            (beef, principal)        0.138217              (beef, studio)
# 4               (girls, coach)        0.293362         (girls, convention)
# 5      (governance, daughters)       -0.098058          (governance, boat)
# 6           (lady, commanders)        0.124951             (lady, factors)
# 7           (tourists, parent)        0.005909        (tourists, switches)
# 8              (bird, viewers)        0.068633               (bird, needs)
# 9       (individual, scholars)        0.010562         (individual, hotel)
# 10         (prisoners, couple)        0.197164           (prisoners, head)
# 11          (musicians, elite)        0.314941      (musicians, technique)
# 12          (commanders, swan)       -0.206838         (commanders, faith)
# 13          (bully, confessor)        0.447301             (bully, tracer)
# 14    (shopkeeper, militarist)        0.237782        (shopkeeper, canyon)
# 15        (fishermen, catcher)        0.131404         (fishermen, social)
# 16         (dispenser, banker)        0.208086         (dispenser, malady)
# 17            (landlord, boss)        0.371443            (landlord, club)
# 18           (council, sister)       -0.043763           (council, radius)
# 19      (eyewitness, referent)        0.165639         (eyewitness, death)
# 20            (junior, misses)        0.149880            (junior, result)
# 21          (shipmates, pilot)        0.235682         (shipmates, denial)
# 22         (buyer, astronomer)       -0.023559      (buyer, collaboration)
# 23    (grandfathers, salesman)        0.122576   (grandfathers, greetings)
# 24    (stewardess, alcoholics)        0.264495   (stewardess, hospitality)
# 25            (nurse, builder)        0.293658          (nurse, phonology)
# 26           (racist, student)        0.165405               (racist, bar)
# 27       (celebrity, humorist)        0.391557      (celebrity, tradition)
# 28         (nationals, bishop)        0.193799        (nationals, economy)
# 29       (artist, householder)        0.292211           (artist, margins)
# 30       (customer, retailers)        0.365891            (customer, cake)
# 31             (giant, female)        0.260256               (giant, foot)
# 32     (controller, craftsman)        0.166813        (controller, essays)
# 33           (poets, sardines)        0.164722             (poets, honour)
# 34            (youths, purist)        0.275726           (youths, fashion)
# 35        (instructor, police)        0.329736     (instructor, departure)
# 36          (graduate, farmer)        0.162104           (graduate, plane)
# 37              (dancers, sea)       -0.116827          (dancers, arcades)
# 38       (suffrage, cosmology)        0.027109         (suffrage, peoples)
# 39       (definition, protest)       -0.131359          (definition, fish)
# 40          (portrait, status)        0.013816    (portrait, commentators)
# 41         (timber, formation)        0.124075           (timber, partner)
# 42        (chronicle, vectors)       -0.235051     (chronicle, communists)
# 43           (policies, panel)        0.161511         (policies, peasant)
# 44     (discrimination, money)        0.315035    (discrimination, master)
# 45  (management, developments)        0.155672        (management, mother)
# 46              (coal, octave)       -0.009159             (coal, dolphin)
# 47              (names, stick)        0.031882               (names, sons)
# 48            (thesis, boards)        0.168429              (thesis, wife)
# 49            (chambers, pans)        0.284302        (chambers, veterans)
# 50      (corruption, suffrage)        0.231313        (corruption, dealer)
# 51     (specimen, wakefulness)        0.241222           (specimen, tiger)
# 52          (engraving, class)       -0.063562       (engraving, neighbor)
# 53            (outrages, menu)        0.128639       (outrages, lifeguard)
# 54  (contentment, appointment)       -0.004119  (contentment, sociologist)
# 55            (meantime, lips)        0.087797          (meantime, sinner)
# 56              (siren, lemon)        0.265571         (siren, postmaster)
# 57      (helicopter, findings)       -0.204585     (helicopter, developer)
# 58    (application, existence)        0.350004      (application, amateur)
# 59        (orchestra, country)       -0.000462        (orchestra, senator)
# 60          (agreement, limit)        0.179189       (agreement, liberals)
# 61        (defeats, criterion)       -0.216664        (defeats, merchants)
# 62        (sequence, lingerie)       -0.056840       (sequence, intruders)
# 63               (hope, press)        0.124513             (hope, cobbler)
# 64                (game, risk)        0.143043            (game, reporter)
# 65         (cigarette, lounge)        0.556372          (cigarette, owner)
# 66        (handwriting, music)        0.203214  (handwriting, millionaire)
# 67           (benefits, month)        0.049007        (benefits, princess)
# 68           (night, airplane)        0.257337            (night, pianist)
# 69              (winter, town)        0.248321           (winter, planner)
# 70           (taint, membrane)        0.114696           (taint, civilian)
# 71      (access, explorations)        0.136902           (access, analyst)
# 72          (milligrams, tape)        0.166171      (milligrams, planters)
# 73            (beginning, ear)       -0.009631      (beginning, champions)
#
#     Simval_contrast
# 0         -0.119413
# 1         -0.099778
# 2         -0.101899
# 3          0.037278
# 4         -0.264332
# 5         -0.177869
# 6         -0.191033
# 7          0.045088
# 8         -0.015839
# 9         -0.214935
# 10         0.154879
# 11         0.259844
# 12         0.064058
# 13         0.369659
# 14         0.133162
# 15        -0.012519
# 16         0.271085
# 17         0.205674
# 18         0.008936
# 19         0.224569
# 20        -0.109769
# 21         0.208171
# 22         0.154351
# 23         0.119145
# 24         0.273858
# 25        -0.095335
# 26        -0.167956
# 27        -0.001513
# 28         0.323665
# 29        -0.183471
# 30         0.073895
# 31         0.278797
# 32        -0.041231
# 33         0.262936
# 34         0.063413
# 35         0.225778
# 36        -0.015886
# 37         0.178737
# 38         0.051773
# 39        -0.148257
# 40        -0.055508
# 41        -0.006049
# 42        -0.073401
# 43         0.173856
# 44        -0.078970
# 45        -0.191371
# 46         0.331514
# 47         0.314139
# 48         0.248838
# 49        -0.038178
# 50        -0.023838
# 51         0.169028
# 52         0.089913
# 53         0.654274
# 54         0.326018
# 55         0.208401
# 56         0.295742
# 57         0.186551
# 58         0.187094
# 59         0.076527
# 60         0.215958
# 61         0.220251
# 62        -0.009885
# 63         0.171368
# 64         0.083672
# 65         0.290501
# 66         0.020170
# 67        -0.272577
# 68         0.031916
# 69        -0.078663
# 70        -0.016507
# 71         0.005300
# 72         0.121747
# 73         0.243973

# %% [markdown]
# Now we export the dataframe to be able to use it for data analysis.

# %%
df_simval.to_csv('df_simval.csv', sep=',', header=False, index=True)
